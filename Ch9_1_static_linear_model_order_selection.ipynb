# %%
# NB: per eseguire questo notebook come file Python, scegliere il menù "File -> Download as -> Python (.py)" .
# Da Canopy, scommentando questa istruzione si hanno i grafici nella console e non in finestre aggiuntive:
#get_ipython().magic(u'matplotlib inline')
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from parsimonious_LS import *
from validation_set import *

# %%
N = 64
maxgp = 12 #N-1
stderr = 0.3 #0.3
vk = np.arange(0.,1.,1./N)
if 0:
    x_veri = np.array([[11.987654321, -5.987654321, -4.987654321, 1.987654321]]).T
    b = np.polyval(x_veri,vk)
else:
    b = np.sin(2*np.pi*vk)
#endif
br = b + stderr*np.random.randn(N);
plt.figure(1), plt.plot(br,'bo'); plt.title('experimental data'); plt.show()
br = np.atleast_2d(br).T

# %%
parsimonious_LS(vk,br,maxgp,stderr)
# aumentando il grado, la stima della varianza dell'errore di predizione (estvar_errpred), che e'
# in sostanza il residuo scalato, scende (cfr. Figura) e al limite (interpolazione) si annulla, 
# pero' la covarianza dell'errore di stima dei parametri aumenta vistosamente.
# Notare che al grado 3 (che è quello giusto per approssimare un periodo di 
# una sinusoide) si ha l'avvicinamento di estvar_errpred al valore vero di varianza del rumore.
# Out:
# estimated parameters:  [[-0.03751334]]
# variance of parameters estimation error:  [0.00946549]
# NCP =  0.028276671073975433
# estimated parameters:  [[-1.94143524  0.91803682]]
# variance of parameters estimation error:  [0.05465297 0.0177929 ]
# NCP =  0.02140704647156161
# estimated parameters:  [[ 0.21332877 -2.15143075  0.95194234]]
# variance of parameters estimation error:  [0.83330227 0.86296426 0.03911805]
# NCP =  0.021378076007459817
# estimated parameters:  [[ 24.41046681 -35.83025113  11.92928457  -0.15740677]]
# variance of parameters estimation error:  [3.27636014 7.35340136 1.30779779 0.01663233]
# NCP =  0.006230490884500297
# estimated parameters:  [[ -7.73798032  39.64461557 -45.42095309  13.98923137  -0.25160072]]
# variance of parameters estimation error:  [5.16682339e+01 2.03532572e+02 8.67063198e+01 4.96602426e+00
#  2.42446282e-02]
# NCP =  0.00614501800569723
# estimated parameters:  [[-33.6448568   75.05990947 -32.52973546 -19.08168298  10.39871101
#    -0.14672291]]
# variance of parameters estimation error:  [8.18131362e+02 5.00611256e+03 3.96710045e+03 5.87556383e+02
#  1.42514670e+01 3.20377498e-02]
# NCP =  0.007146683653378481
# estimated parameters:  [[-1.43120474e+02  3.89007792e+02 -3.96332986e+02  2.12945127e+02
#   -7.83712857e+01  1.59716545e+01 -2.56989334e-01]]
# variance of parameters estimation error:  [1.29851813e+04 1.14053147e+05 1.45824180e+05 4.21275688e+04
#  2.81020751e+03 3.37995289e+01 3.94297362e-02]
# NCP =  0.007126206062742167
# estimated parameters:  [[ 3.74779853e+01 -2.72243845e+02  5.64584143e+02 -5.15615937e+02
#    2.55093629e+02 -8.56418733e+01  1.64692927e+01 -2.63913020e-01]]
# variance of parameters estimation error:  [2.12916330e+05 2.54057029e+06 4.78899821e+06 2.30522749e+06
#  3.12165143e+05 1.08730598e+04 7.19381481e+01 4.73957095e-02]
# NCP =  0.00719774388561612
# estimated parameters:  [[-1.26857674e+03  5.03249892e+03 -8.28769149e+03  7.29469193e+03
#   -3.67017722e+03  1.06832978e+03 -1.90994301e+02  2.19282122e+01
#   -3.18596308e-01]]
# variance of parameters estimation error:  [3.48064533e+06 5.41785838e+07 1.41522677e+08 1.02800312e+08
#  2.38506539e+07 1.74559917e+06 3.49842385e+04 1.37088072e+02
#  5.43226559e-02]
# NCP =  0.007470945258857707
# estimated parameters:  [[-7.66310224e+03  3.26765714e+04 -5.77641764e+04  5.45674469e+04
#   -2.95534355e+04  9.11494072e+03 -1.45366249e+03  6.33909813e+01
#    1.16523089e+01 -2.43453261e-01]]
# variance of parameters estimation error:  [5.66051302e+07 1.11419430e+09 3.85535424e+09 3.94973258e+09
#  1.41155913e+09 1.81400787e+08 7.87559121e+06 9.73401934e+04
#  2.38784517e+02 5.97287832e-02]
# NCP =  0.008399551291771404
# estimated parameters:  [[ 6.24107775e+03 -3.83809068e+04  9.70437004e+04 -1.32617511e+05
#    1.07350081e+05 -5.27019858e+04  1.53401506e+04 -2.42592003e+03
#    1.41879298e+02  9.12241137e+00 -2.29864684e-01]]
# variance of parameters estimation error:  [9.43687344e+08 2.29190962e+10 1.01519373e+11 1.39688408e+11
#  7.15306903e+10 1.44225504e+10 1.12386442e+09 3.09290548e+07
#  2.48429047e+05 3.98272309e+02 6.52864895e-02]
# NCP =  0.008407352879290342
# estimated parameters:  [[ 9.46734788e+04 -5.06327054e+05  1.16158860e+06 -1.49337984e+06
#    1.17951016e+06 -5.90417660e+05  1.86735028e+05 -3.62318582e+04
#    4.11918190e+03 -2.90397549e+02  2.04569881e+01 -2.74572350e-01]]
# variance of parameters estimation error:  [1.58397564e+10 4.65264796e+11 2.56797491e+12 4.57297244e+12
#  3.18390557e+12 9.32713740e+11 1.15880034e+11 5.83460203e+09
#  1.06910319e+08 5.80795446e+05 6.28631011e+02 6.93496420e-02]
# NCP =  0.008706551128213329
# estimated parameters:  [[-1.94853442e+05  1.24552662e+06 -3.48344929e+06  5.59222090e+06
#   -5.68291179e+06  3.80277642e+06 -1.68989804e+06  4.91502196e+05
#   -9.01323571e+04  9.79412705e+03 -6.02684116e+02  2.72302280e+01
#   -2.94075669e-01]]
# variance of parameters estimation error:  [-1.82846971e+11 -6.47951512e+12 -4.38640237e+13 -9.77292046e+13
#  -8.72117170e+13 -3.37258162e+13 -5.73403071e+12 -4.12289910e+11
#  -1.12536601e+10 -8.97072274e+07 -3.92496394e+04  3.25227310e+02
#   6.75757643e-02]
# NCP =  0.008566920118862063

# %%
# avvicinarsi all'interpolante è numericamente instabile:
N = 36
maxgp = N-1
vk = np.arange(0.,1.,1./N)
br = np.asmatrix( np.sin(2*np.pi*vk) + stderr*np.random.randn(N) ).T
parsimonious_LS(vk,br,maxgp,stderr)

# %%
# validazione del modello: "validation set"
# consideriamo due insiemi di dati, formati ciascuno da una sola serie storica (in un caso reale ne useremmo piu' di uno)
# il primo, "br", lo usiamo per il training del modello, mentre il secondo, "br_test", lo usiamo per il test:
N = 20
maxgp = N-1
vk = np.arange(0.,1.,1./N)
b = np.sin(2*np.pi*vk)
stderr = 0.3
br = np.asmatrix( b + stderr*np.random.randn(N) ).T
br_test = np.asmatrix( b + stderr*np.random.randn(N) ).T
validation_set(vk,br,br_test,maxgp)
